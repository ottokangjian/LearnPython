# %%
#!/usr/bin/env python3
# -*- coding:utf-8 -*-
import numpy as np
from basic import *
from sklearn.feature_extraction.text import CountVectorizer
import lda
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def get_lda_input(chapters):
    corpus = [" ".join(word_list) for word_list in chapters]
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(corpus)
    return X.toarray(), vectorizer

# %%
def lda_train(weight, vectorizer):
    model = lda.LDA(n_topics=20, n_iter=1000, random_state=1)
    model.fit(weight)

    doc_num = len(weight)
    topic_word = model.topic_word_
    vocab = vectorizer.get_feature_names()
    titles = ["第{}章".format(i) for i in range(1, doc_num + 1)]

    n_top_words = 20
    for i, topic_dist in enumerate(topic_word):
        topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words + 1):-1]
        print('Topic {}: {}'.format(i, ' '.join(topic_words)))

    doc_topic = model.doc_topic_
    print(doc_topic, type(doc_topic))
    plot_topic(doc_topic)
    for i in range(doc_num):
        print("{} (top topic: {})".format(titles[i], np.argsort(doc_topic[i])[:-4:-1]))

# %%
def main():
    chapter_list = split_by_chapter("data/芳华-严歌苓.txt")
    chapters = MyChapters(chapter_list)
    weight, vectorizer = get_lda_input(chapters)
    lda_train(weight, vectorizer)

# %%
def plot_topic(doc_topic):
    f, ax = plt.subplots(figsize=(10, 4))
    cmap = sns.cubehelix_palette(start=1, rot=3, gamma=0.8, as_cmap=True)
    sns.heatmap(doc_topic, cmap=cmap, linewidths=0.05, ax=ax)
    ax.set_title('proportion per topic in every chapter')
    ax.set_xlabel('topic')
    ax.set_ylabel('chapter')
    plt.show()
    
    f.savefig('output/topic_heatmap.jpg', bbox_inches='tight')

# %%
if __name__ == '__main__':
    main()
# Out:
# INFO:lda:n_documents: 15
# INFO:lda:vocab_size: 6711
# INFO:lda:n_words: 17269
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 1000
# INFO:lda:<0> log likelihood: -218507
# INFO:lda:<10> log likelihood: -171148
# INFO:lda:<20> log likelihood: -166263
# INFO:lda:<30> log likelihood: -164207
# INFO:lda:<40> log likelihood: -162895
# INFO:lda:<50> log likelihood: -161769
# INFO:lda:<60> log likelihood: -161343
# INFO:lda:<70> log likelihood: -160566
# INFO:lda:<80> log likelihood: -160219
# INFO:lda:<90> log likelihood: -160222
# INFO:lda:<100> log likelihood: -160068
# INFO:lda:<110> log likelihood: -159750
# INFO:lda:<120> log likelihood: -159776
# INFO:lda:<130> log likelihood: -159705
# INFO:lda:<140> log likelihood: -159356
# INFO:lda:<150> log likelihood: -159140
# INFO:lda:<160> log likelihood: -159232
# INFO:lda:<170> log likelihood: -159002
# INFO:lda:<180> log likelihood: -158959
# INFO:lda:<190> log likelihood: -159091
# INFO:lda:<200> log likelihood: -158893
# INFO:lda:<210> log likelihood: -158809
# INFO:lda:<220> log likelihood: -158742
# INFO:lda:<230> log likelihood: -158757
# INFO:lda:<240> log likelihood: -158745
# INFO:lda:<250> log likelihood: -158453
# INFO:lda:<260> log likelihood: -158686
# INFO:lda:<270> log likelihood: -158530
# INFO:lda:<280> log likelihood: -158477
# INFO:lda:<290> log likelihood: -158517
# INFO:lda:<300> log likelihood: -158610
# INFO:lda:<310> log likelihood: -158430
# INFO:lda:<320> log likelihood: -158935
# INFO:lda:<330> log likelihood: -158307
# INFO:lda:<340> log likelihood: -158488
# INFO:lda:<350> log likelihood: -158352
# INFO:lda:<360> log likelihood: -158287
# INFO:lda:<370> log likelihood: -158289
# INFO:lda:<380> log likelihood: -158464
# INFO:lda:<390> log likelihood: -157962
# INFO:lda:<400> log likelihood: -158111
# INFO:lda:<410> log likelihood: -158312
# INFO:lda:<420> log likelihood: -158246
# INFO:lda:<430> log likelihood: -158028
# INFO:lda:<440> log likelihood: -158237
# INFO:lda:<450> log likelihood: -158438
# INFO:lda:<460> log likelihood: -158201
# INFO:lda:<470> log likelihood: -157779
# INFO:lda:<480> log likelihood: -158023
# INFO:lda:<490> log likelihood: -157730
# INFO:lda:<500> log likelihood: -157804
# INFO:lda:<510> log likelihood: -158503
# INFO:lda:<520> log likelihood: -158617
# INFO:lda:<530> log likelihood: -157973
# INFO:lda:<540> log likelihood: -158322
# INFO:lda:<550> log likelihood: -158097
# INFO:lda:<560> log likelihood: -157903
# INFO:lda:<570> log likelihood: -158301
# INFO:lda:<580> log likelihood: -158207
# INFO:lda:<590> log likelihood: -158117
# INFO:lda:<600> log likelihood: -158066
# INFO:lda:<610> log likelihood: -158471
# INFO:lda:<620> log likelihood: -158185
# INFO:lda:<630> log likelihood: -157740
# INFO:lda:<640> log likelihood: -158033
# INFO:lda:<650> log likelihood: -157804
# INFO:lda:<660> log likelihood: -157988
# INFO:lda:<670> log likelihood: -157731
# INFO:lda:<680> log likelihood: -157766
# INFO:lda:<690> log likelihood: -158062
# INFO:lda:<700> log likelihood: -157658
# INFO:lda:<710> log likelihood: -157773
# INFO:lda:<720> log likelihood: -157776
# INFO:lda:<730> log likelihood: -157547
# INFO:lda:<740> log likelihood: -157610
# INFO:lda:<750> log likelihood: -157398
# INFO:lda:<760> log likelihood: -157700
# INFO:lda:<770> log likelihood: -157335
# INFO:lda:<780> log likelihood: -157557
# INFO:lda:<790> log likelihood: -157626
# INFO:lda:<800> log likelihood: -157519
# INFO:lda:<810> log likelihood: -157533
# INFO:lda:<820> log likelihood: -157735
# INFO:lda:<830> log likelihood: -157666
# INFO:lda:<840> log likelihood: -157773
# INFO:lda:<850> log likelihood: -157399
# INFO:lda:<860> log likelihood: -157562
# INFO:lda:<870> log likelihood: -157450
# INFO:lda:<880> log likelihood: -157415
# INFO:lda:<890> log likelihood: -157440
# INFO:lda:<900> log likelihood: -157377
# INFO:lda:<910> log likelihood: -157108
# INFO:lda:<920> log likelihood: -157272
# INFO:lda:<930> log likelihood: -157509
# INFO:lda:<940> log likelihood: -157432
# INFO:lda:<950> log likelihood: -157308
# INFO:lda:<960> log likelihood: -157163
# INFO:lda:<970> log likelihood: -157258
# INFO:lda:<980> log likelihood: -157089
# INFO:lda:<990> log likelihood: -156995
# INFO:lda:<999> log likelihood: -156750
# Topic 0: 小惠 郝淑雯 少俊 好人 啤酒 看着 生意 老板 刘大哥 老战友 发廊 老公 邻居 汽车 背叛 城管 出卖 眼线 惠雅玲 路灯
# Topic 1: 年轻 女人 照片 眼睛 想到 生命 跟着 来到 笑笑 院子 回去 房间 好看 军区 结婚 接受 打开 听说 坐在 关系
