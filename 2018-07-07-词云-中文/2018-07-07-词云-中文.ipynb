# %%
filename = "test.txt"
with open(filename) as f:
 mytext = f.read()

print(mytext)

import jieba
mytext = " ".join(jieba.cut(mytext))

print(mytext)
# Out:
# 关于销售与投研衔接的建议及案例
#
# 2018 年 6 月 25 日
#
# 关于投研部的成立以及营销部出差的文字报告制度，可能不少营销部同事因为没 有接触过国际贸易公司的投研系统，存在一些疑问。
#
# 国际贸易公司的投研工作方式：摒弃对基本面的感性认识，将获取到的基本面信 息数据化、具象化，通过直观的数字及图表，反应出基本面的走势，做为研究行 情后续变化的理论依据。
#
# 因此，做为与终端市场接触最为密切的营销部，是投研部获取一手准确的市场信 息的重要渠道。营销部与客户的沟通方式和信息整合方式，可能需要适应投研部 的研究方式。
#
# e.g. 以前营销人员与某一区域几家工厂聊天，发现普遍缺造球精粉，但可能不清 楚因何原因导致精粉短缺，会缺多长时间。
#
# 而投研部需要的数据是：
#
# 1. 几家工厂各自外购球团在生产中的比例如何，当前球团溢价对比之前球团溢 价的有何变化；
#
# 2. 当前的造球精粉在生产中配比如何，对比之前球精的配比发生了什么变化；
#
# 3. 伴随造球精粉配比变化的，还有什么其他品种配料的变化，比如烧结矿构成 变化，焦炭、焦煤或者其他辅料的变化；
#
# 4. 当地区域是否收到诸如环保限竖炉，限烧结之类政策性因素的影响。
#
# 而最终投研部所有研究结果可能汇总在几张图中：
#
# 1. 造球精粉主要生产商发运量汇总分时图
#
# 2. 进口造球精粉到港量分时图（具化到相关区域钢厂对应发货港的到港分时图）
#
# 3. 国产精粉开工率分时图（具化到相关区域周边的国产精粉开工率分时图）
#
# 4. 样本工厂造球精粉配料比例分时图
#
# 5. 样本球团厂开工率分时图
#
# 6. 造球精粉市场溢价变化分时图 通过这些图表来研究造球精粉短缺的原因是什么，再从供求以及区域影响来判断 大概的持续时间，以及溢价合理的变化区间，最终形成一个有效的策略：在多长 的时间区间内，多大的溢价范围内，去购买造球精粉，供应到哪些地区，应该在 什么价格区间内售出。
# 关于 销售 与 投研 衔接 的 建议 及 案例
#
#  2018   年   6   月   25   日
#
#  关于 投研部 的 成立 以及 营销部 出差 的 文字 报告 制度 ， 可能 不少 营销部 同事 因为 没   有 接触 过 国际贸易 公司 的 投研 系统 ， 存在 一些 疑问 。
#
#  国际贸易 公司 的 投研 工作 方式 ： 摒弃 对 基本面 的 感性认识 ， 将 获取 到 的 基本面 信   息 数据 化 、 具象化 ， 通过 直观 的 数字 及 图表 ， 反应 出 基本面 的 走势 ， 做 为 研究 行   情 后续 变化 的 理论依据 。
#
#  因此 ， 做 为 与 终端 市场 接触 最为 密切 的 营销部 ， 是 投 研部 获取 一手 准确 的 市场 信   息 的 重要 渠道 。 营销部 与 客户 的 沟通 方式 和 信息 整合 方式 ， 可能 需要 适应 投研部   的 研究 方式 。
#
#  e . g .   以前 营销 人员 与 某 一 区域 几家 工厂 聊天 ， 发现 普遍 缺造球 精粉 ， 但 可能 不清   楚因 何原因 导致 精粉 短缺 ， 会缺 多长时间 。
#
#  而 投 研部 需要 的 数据 是 ：
#
#  1 .   几家 工厂 各自 外购 球团 在 生产 中 的 比例 如何 ， 当前 球团 溢价 对比 之前 球团 溢   价 的 有何 变化 ；
#
#  2 .   当前 的 造球 精粉 在 生产 中 配比 如何 ， 对比 之前 球精 的 配比 发生 了 什么 变化 ；
#
#  3 .   伴随 造球 精粉 配比 变化 的 ， 还有 什么 其他 品种 配料 的 变化 ， 比如 烧结 矿 构成   变化 ， 焦炭 、 焦煤 或者 其他 辅料 的 变化 ；
#
#  4 .   当地 区域 是否 收到 诸如 环保 限 竖炉 ， 限 烧结 之类 政策性 因素 的 影响 。
#
#  而 最终 投研部 所有 研究 结果 可能 汇总 在 几张 图中 ：
#
#  1 .   造球 精粉 主要 生产商 发 运量 汇总 分时图
#
#  2 .   进口 造球 精粉 到 港量 分时图 （ 具化 到 相关 区域 钢厂 对应 发货 港 的 到 港 分时图 ）
#
#  3 .   国产 精粉 开工率 分时图 （ 具化 到 相关 区域 周边 的 国产 精粉 开工率 分时图 ）
#
#  4 .   样本 工厂 造球 精粉 配料 比例 分时图
#
#  5 .   样本 球团 厂 开工率 分时图
#
#  6 .   造球 精粉 市场 溢价 变化 分时图   通过 这些 图表 来 研究 造球 精粉 短缺 的 原因 是 什么 ， 再 从 供求 以及 区域 影响 来 判断   大概 的 持续时间 ， 以及 溢价 合理 的 变化 区间 ， 最终 形成 一个 有效 的 策略 ： 在 多长   的 时间 区间 内 ， 多大 的 溢价 范围 内 ， 去 购买 造球 精粉 ， 供应 到 哪些 地区 ， 应该 在   什么 价格 区间 内 售出 。

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(font_path="simsun.ttf").generate(mytext)
# %pylab inline
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/jiankang/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# (-0.5, 399.5, 199.5, -0.5)
