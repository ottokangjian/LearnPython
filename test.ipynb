# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x = np.arange(120)
y = x ** 2

plt.plot(x, y)

# %%
import tushare as ts

ts.get_hist_data('600848') #一次性获取全部数据
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# date
# 2018-06-14  21.76  21.94  21.68  21.56   15457.00         -0.07     -0.32
# 2018-06-13  22.00  22.14  21.76  21.74   15149.00         -0.32     -1.45
# 2018-06-12  21.94  22.15  22.08  21.77   16061.00          0.14      0.64
# 2018-06-11  22.01  22.16  21.95  21.81   15324.49         -0.06     -0.27
# 2018-06-08  22.16  22.16  22.00  21.81   23499.00         -0.32     -1.43
# 2018-06-07  22.88  22.88  22.33  22.23   32495.78         -0.29     -1.28
# 2018-06-06  23.10  23.23  22.68  22.48   63223.83          0.65      2.95
# 2018-06-05  21.73  22.05  22.03  21.69   19257.19          0.30      1.38
# 2018-06-04  21.82  22.07  21.73  21.53   18135.00          0.00      0.00
# 2018-06-01  22.12  22.12  21.73  21.61   25226.00         -0.33     -1.50
# 2018-05-31  21.88  22.25  22.08  21.80   29562.00          0.40      1.84
# 2018-05-30  22.48  22.68  21.69  21.66   59913.80         -1.22     -5.33
# ...

# %%
##股票列表：调用方法：
import tushare as ts
ts.get_stock_basics()        
          


##业绩报告：
##按年度、季度获取业绩报表数据。数据获取需要一定的时间，网速取决于您的网速.调用方法：
ts.get_report_data(2017,1)



##盈利能力：按年度、季度获取盈利能力数据
ts.get_profit_data(2017,1)



##营运能力：按年度、季度获取营运能力数据
ts.get_operation_data(2017,1)



##成长能力：按年度、季度获取成长能力数据
ts.get_growth_data(2017,1)

##偿债能力：按年度、季度获取偿债能力数据
ts.get_debtpaying_data(2017,1)

##现金流量：调用方式：
ts.get_cashflow_data(2017,1)
# Out:
# [Getting data:]###########################################################[Getting data:]###########################################################[Getting data:]###########################################################[Getting data:]#######################################################[Getting data:]###########################################################[Getting data:]###########################################################
#         code   name  cf_sales  rateofreturn     cf_nm  cf_liabilities  \
# 0     000534   万泽股份  106.0343        0.0664       NaN          0.1423
# 1     000627   天茂集团   56.8236        0.0708   39.2436          0.0844
# 2     000918    嘉凯城   12.6572        0.0720       NaN          0.0808
# 3     000638   万方发展   12.2882        0.1937       NaN          0.2317
# 4     002828   贝肯能源    9.7640        0.0465       NaN          0.3282
# 5     000567   海德股份    9.2533        0.2936   19.9289          0.3613
# ...
